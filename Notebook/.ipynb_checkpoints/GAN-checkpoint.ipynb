# %% [markdown]
# # Generative Adversarial Network
# Practise for implementing a basic GAN

# %% [markdown]
# ## Theory
# - two nets fight together, generator tries to fool the discrimeter with fake examples, discrimeter net tries to figure out wheter the generator is lying
# - generator loss: $-\log (D(G(z))$, maximize the score given by the discrimeter
# - discriminator loss: $-[\log(D(x) + \log(1 - D(G(z))]$, maximize the probability from real samples $x$ and minimize probabilities from fake examples $G(z)$

# %% [markdown]
# ![overview of gan](http://www.timzhangyuxuan.com/static/images/project_DCGAN/structure.png)

# %% [markdown]
# ## Geneate MINIST pictures with GAN
# ** MNIST Dataset Overview**
#
# This example is using MNIST handwritten digits. The dataset contains 60,000 examples for training and 10,000 examples for testing. The digits have been size-normalized and centered in a fixed-size image (28x28 pixels) with values from 0 to 1. For simplicity, each image has been flattened and converted to a 1-D numpy array of 784 features (28*28).
#
# ![MNIST Dataset](http://neuralnetworksanddeeplearning.com/images/mnist_100_digits.png)

# %% [markdown]
# # Implementation

# %% [markdown]
# ## Import modules

# %%
from __future__ import division, print_function, absolute_import

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
# %matplotlib inline

# %% [markdown]
# ## Import dataset

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Hyper parameters

# %%
num_steps = 70000

batch_size = 128
learning_rate = 2e-4

image_dim = 28*28
gen_hidden_dim = 256
disc_hidden_dim = 256
input_z = 100 # input of generator

def init_weight(shape):
    return tf.random_normal(shape=shape, stddev = 1. / tf.sqrt(shape[0] / 2.0) )

# %%
# Weights
weights = {'gen_hidden1':tf.Variable(init_weight([input_z, gen_hidden_dim])),
           'gen_out':tf.Variable(init_weight([gen_hidden_dim, image_dim])),
           'disc_hidden1':tf.Variable(init_weight([image_dim, disc_hidden_dim])),
           'disc_out':tf.Variable(init_weight([disc_hidden_dim, 1]))
          }

bias = {'gen_hidden1':tf.Variable(tf.zeros(gen_hidden_dim)),
        'gen_out':tf.Variable(tf.zeros(image_dim)),
        'disc_hidden1':tf.Variable(tf.zeros(disc_hidder_dim)),
        'disc_out':tf.Variable(tf.zeros(1))
       }

gen_input = tf.placeholder(tf.float32, [None, input_z], name='gen_input')
disc_input = tf.placeholder(tf.float32, [None, image_dim], name='disc_input')

gen_var_list = [weights['gen_hidden1'], bias['gen_hidden1'], weights['gen_out'], bias['gen_out']]
disc_var_list = [weights['disc_hidden1'], bias['disc_hidden1'], weights['disc_out'], bias['disc_out']]

# %% [markdown]
# ## Network architecture

# %%
def generator(x):
    hidden_layer = tf.matmul(x, weights['gen_hidden1'])
    hidden_layer = tf.add(hidden_layer, bias['gen_hidden1'])
    hidden_layer = tf.nn.relu(hidden_layer)
    out_layer = tf.matmul(hidden_layer, weights['gen_out'])
    out_layer = tf.add(out_layer, bias['gen_out'])
    out_layer = tf.nn.sigmoid(out_layer)
    return out_layer
    
    
def discriminator(disc_input):
    hidden_layer = tf.matmul(disc_input, weights['disc_hidden1'])
    hidden_layer = tf.add(hidden_layer, bias['disc_hidden1'])
    hidden_layer = tf.nn.relu(hidden_layer)
    out_layer = tf.matmul(hidden_layer, weights['disc_out'])
    out_layer = tf.add(out_layer, bias['disc_out'])
    out_layer = tf.nn.sigmoid(out_layer)
    return out_layer

# %% [markdown]
# ## Construct model

# %%
gen_out = generator(gen_input)
disc_real = discriminator(disc_input)
disc_fake = discriminator(gen_out)

# %% [markdown]
# ## Loss

# %%
gen_loss = -tf.reduce_mean(tf.log(disc_fake))
disc_loss = -tf.reduce_mean(tf.log(disc_real) + tf.log(1. - disc_fake))

# Optimizer
gen_opt = tf.train.AdadeltaOptimizer(
    learning_rate).minimize(gen_loss, var_list=gen_var_list)
disc_opt = tf.train.AdamOptimizer(learning_rate).minimize(
    disc_loss, var_list=disc_var_list)

# %% [markdown]
# ## Training

# %%
init = tf.global_variables_initializer()
loss_array = []
sess = tf.Session()

sess.run(init)
for step in range(1, num_steps+1):
    batch_x, _ = mnist.train.next_batch(batch_size)
    z = np.random.uniform(-1., 1., size=[batch_size, input_z])

    _, _, g_loss, d_loss = sess.run([gen_opt, disc_opt, gen_loss, disc_loss], feed_dict={
                                    gen_input: z, disc_input: batch_x})
    
    if step % 10 == 0 or step== 1:
        loss_array.append([step, g_loss, d_loss])

    if step % 2000 == 0 or step == 1:
        print ("step:{}, generator loss:{}, discriminator loss:{}".format(step, g_loss, d_loss))
# Out:
# step:1, generator loss:0.756309747696, discriminator loss:1.5001718998
# step:2000, generator loss:11.2629547119, discriminator loss:0.0001372458064
# step:4000, generator loss:12.8435087204, discriminator loss:2.41342877416e-05
# step:6000, generator loss:14.1349573135, discriminator loss:2.46359445555e-06
# step:8000, generator loss:15.3810825348, discriminator loss:8.20937998469e-07
# step:10000, generator loss:16.5299987793, discriminator loss:1.70612167949e-07
# step:12000, generator loss:17.5469932556, discriminator loss:1.44933537172e-07
# step:14000, generator loss:18.4374351501, discriminator loss:8.48747845339e-08
# step:16000, generator loss:19.407617569, discriminator loss:4.13981560143e-08
# step:18000, generator loss:20.2627353668, discriminator loss:4.95610095186e-08
# step:20000, generator loss:20.8846492767, discriminator loss:5.76216407921e-08
# step:22000, generator loss:21.2572402954, discriminator loss:5.96242557549e-08
# step:24000, generator loss:22.4233016968, discriminator loss:4.75985260096e-08
# step:26000, generator loss:22.6901054382, discriminator loss:1.4421245309e-09
# step:28000, generator loss:23.1552028656, discriminator loss:1.40351810174e-08
# step:30000, generator loss:23.5592765808, discriminator loss:8.55949622292e-09
# step:32000, generator loss:23.9119052887, discriminator loss:4.73739136808e-09
# step:34000, generator loss:25.6630115509, discriminator loss:2.60901060756e-08
# step:36000, generator loss:24.4883460999, discriminator loss:8.74945627061e-08
# step:38000, generator loss:25.7543697357, discriminator loss:4.87756457446e-09
# step:40000, generator loss:26.3377609253, discriminator loss:1.27451018628e-08
# step:42000, generator loss:27.1330947876, discriminator loss:1.12895484961e-07
# step:44000, generator loss:31.2518291473, discriminator loss:1.84776837386e-07
# step:46000, generator loss:27.0100421906, discriminator loss:7.10146821348e-07
# step:48000, generator loss:29.9711723328, discriminator loss:7.61161231821e-07
# step:50000, generator loss:29.2159290314, discriminator loss:1.74011205445e-08
# step:52000, generator loss:30.1515865326, discriminator loss:4.72924028827e-07
# step:54000, generator loss:31.1720294952, discriminator loss:1.168257171e-07
# step:56000, generator loss:31.8366298676, discriminator loss:5.01417432019e-08
# step:58000, generator loss:31.1032981873, discriminator loss:4.26145589927e-08
# step:60000, generator loss:30.1223239899, discriminator loss:8.48390300234e-07
# step:62000, generator loss:28.9424800873, discriminator loss:1.19407687293e-07
# step:64000, generator loss:31.0857925415, discriminator loss:4.43012794449e-07
# step:66000, generator loss:28.4089450836, discriminator loss:2.10568884995e-07
# step:68000, generator loss:28.7279548645, discriminator loss:6.22269666906e-08
# step:70000, generator loss:28.7514400482, discriminator loss:2.047026328e-06

# %%
# plot
loss = np.array(loss_array)

plt.plot(loss[:,0], loss[:,1],'r', loss[:,0], loss[:,2], 'b')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Generator loss & discriminator loss')
plt.legend(('generator loss', 'discriminator loss'))
plt.show()

# %% [markdown]
# ## Test

# %%
# Testing
# Generate images from noise, using the generator network.
n = 6
canvas = np.empty((28 * n, 28 * n))
for i in range(n):
    # Noise input.
    z = np.random.uniform(-1., 1., size=[n, input_z])
    # Generate image from noise.
    g = sess.run(gen_out, feed_dict={gen_input: z})
    # Reverse colours for better display
    g = -1 * (g - 1)
    for j in range(n):
        # Draw the generated digits
        canvas[i * 28:(i + 1) * 28, j * 28:(j + 1) * 28] = g[j].reshape([28, 28])

plt.figure(figsize=(n, n))
plt.imshow(canvas, origin="upper", cmap="gray")
plt.show()
